# %% [markdown]
# Chemical kinetics principles are applied to understand the protein-ligand interactions assuming that when a ligand (or drug) binds to protein it results in biological response. The biological response is proportional to the amount of drug-protein complex formed. The response is decreased when the complex is dissociated.
#
# A protein P binds to Ligand L. The equilibrium expression is:
#
# $ P+L \rightleftharpoons PL$
#
#  Equilibrium constant ($k_{a}$) = $ \frac{[PL]}{[P][L]} $
#
#  Dissociation constant ($k_{d}$) = $ \frac{[P][L]}{[PL]} $
#
#  <mark> Note: Dropped the section on association constant and portion explaining: [p], [L],[PL]
#
#
# $k_{d}$ provides the strngth of interaction between the protein and the ligand and how easy to seperate them.
#
# Thus, the lower the $k_{d}$ value the better the binding is.
#
# Typically for drug-protein interactions, $1x10^{-6}$(1uM) is weak binding, $1x10^{-9}$(1nM) is strong binding.

# %% [markdown]
# <mark> Need to merge into one section and make rest formulas.</mark>
#
# ## **1.2 Residence Time of Ligand or Drug in the Cavity**
#
# ####**Concept:**
# During the binding of a drug or ligand with a protein, the ligand does not remain permanently in the protein's binding site. Instead, it "hops" between the outside solvent molecules and the protein binding site. This dynamic behavior can be visualized with an analogy: imagine two boys playing catch with a ball. The protein's binding site and the surrounding solvent act as "players," while the ligand is the ball.
#
# ####**Key Points:**
#
# 1. **Residence Time**:
#    The **residence time** refers to the duration the ligand stays bound to the protein's binding site.
#
#    If strong **hydrogen bonding** and **hydrophobic interactions** hold the ligand tightly, the residence time is longer.
#
# 2. **Induced Fit**:
#    Just as a hand adjusts to hold a ball tightly, a protein can undergo slight conformational changes to better fit the ligand. This phenomenon is called **induced fit**.
#
# 3. **Impact on `Kd`**:
#    A **longer residence time** correlates with better binding affinity, represented by lower `Kd` values (e.g., from nanomolar (`nM`) to picomolar (`pM`) or femtomolar (`fM`)).
#
# **Analogy: Holding a Ball**
# **Few fingers holding the ball**: Represents weak binding with fewer interactions, resulting in a higher `Kd` (weaker affinity).
#
# **All fingers holding the ball tightly**: Represents strong binding with multiple non-covalent interactions, resulting in a lower `Kd` (stronger affinity).
#
# **Binding Affinity and Free Energy**
#
# The binding affinity (`Kd`) depends on the free energy of binding (`ΔG`), which is influenced by non-covalent interactions. The relationship is given by:
#
# ```
# ΔG = -RTln(Kd)
# ```
#
# Where:
# - `ΔG`: Free energy of binding.
# - `R`: Gas constant.
# - `T`: Temperature in Kelvin.
# - `K_d`: Dissociation constant.
#
# The total free energy (`ΔG`) is the sum of contributions from various interactions:
#
# ```
# ΔG = ΔG (hydrogen bonding) + ΔG (electrostatic interactions) + ΔG (hydrophobic interactions)
# ```
#
# **Dependence on 3D Structure:**
# - The strength of these interactions—and thus the `Kd` value—depends on the **3D structure** of the protein and the ligand. Proper alignment and compatibility of these structures enable optimal binding and lower `Kd` values.

# %% [markdown]
# ### Activities:
# <mark> Optional Activity. Adjust to 2 different pml script to run then keep other stuff. </mark>

# %% [markdown]
# ### 🌟 **Activity: Visualizing `Kd` or Binding Affinity in Terms of Non-Covalent Interactions**
#
# In this activity, we will visualize protein-ligand interactions and their corresponding `Kd` values. We will compare two complexes:
# 1. A complex with a `Kd` value in the nanomolar range.
# 2. A complex with a `Kd` value in the femtomolar range (`10^-15 M`).
#
# #### **Step 1: Visualize the Epidermal Growth Factor Receptor Kinase Complex with Gefitinib**
# The crystal structure of **epidermal growth factor receptor kinase** complexed with the anticancer drug **gefitinib** will be used.
#
# 1. **Fetch the structure in PyMOL:**
#    ```
#    fetch 4i22
#    ```
#
# 2. **Display the sequence:**
#    Use the sequence viewer in PyMOL.
#
# 3. **Select and remove water molecules:**
#    ```
#    remove solvent
#    ```
#
# 4. **Apply visualization presets:**
#    ```
#    A > preset > ligand > cartoon
#    ```
#
#    - The ligand site is displayed.
#    - Observe that the ligand is shown in **sticks** and part of it is outside the protein, exposed to the solvent.
#    - The ligand interacts with the receptor via **hydrophobic interactions**.
#    - The `K_d` value for this interaction is in the **nanomolar (nM)** range.
#
# #### **Step 2: Reinitialize PyMOL**
# Reinitialize everything to start a fresh session:
#
# ```
# reinitialize
# ```
#
# #### **Step 3: Visualize the Avidin-Biotin Complex**
# Next, we will visualize the **avidin** complex with **biotin**, which has one of the highest binding affinities known.
#
# 1. **Fetch the structure in PyMOL:**
#    ```
#    fetch 6j6j
#    ```
#
# 2. **Display the sequence:**
#    Use the sequence viewer in PyMOL.
#
# 3. **Select chains and remove atoms:**
#    From the sequence display, select `chains C, D, and E`, and remove their atoms.
#
#    Retain the first `BTN` and select **BTN from the second onwards**, along with water molecules, and remove them:
#      ```
#      remove chain C+D+E
#      remove resn HOH
#      ```
#
# 4. **Apply visualization presets:**
#    ```
#    A > preset > ligand site > cartoon
#    ```
#
#    Biotin is displayed in **sticks**, and avidin is shown in its **secondary structure**.
#
#    Notice:
#      - **Hydrogen bonding** at both ends of the molecule.
#      - **Hydrophobic interactions** between biotin and avidin.
#      - The entire biotin molecule is trapped in a barrel-shaped protein.
#
#    The `Kd` value for the biotin-avidin complex is in the **femtomolar (10^-15 M)** range.
#
# **Observation:**
# Compare the binding affinities:
# - Nanomolar range (`nM`): Moderate binding affinity, as seen with the gefitinib-receptor complex.
# - Femtomolar range (`10^-15 M`): Extremely high binding affinity, as seen with the biotin-avidin complex.
#
# This activity demonstrates how structural features of protein-ligand interactions influence binding affinities, which is critical in understanding molecular interactions in drug discovery.

# %% [markdown]
# <mark> Optional, put as a quiz instead </mark>
# ### 🌟**Activity: Losartan and Candesartan Residence Time and Clinical Significance**
#
# Losartan and candesartan bind to angiotensin II receptors. A comparison of the in vitro pharmacology of the two antagonists determined that Candesartan has a dissociative half-life of 66–152 min while Losartan has dissociative half-life of 5 min. Based on this information, which drug has a lower $K_d$ value and hence binds to the angiotensin II receptor with higher affinity?
#
# **Clinical Relevance:**
# The clinical efficacy of losartan and candesartan in hypertensive patients suggested that candesartan produced a significant reduction in blood pressure at lower doses (16 mg/day) compared to losartan (100 mg/day).
#
# **References:**
# 1. Copeland RA, Pompliano DL, Meek TD. Drug-target residence time and its implications for lead optimization. Nat Rev Drug Discov. 2006;5(9):730-739.
# 2. Jois. American Journal of Pharmaceutical Education 2010; 74 (8) Article 147.
